# %%
import pandas as pd
import seaborn as sb

# %%
students_performance = pd.read_csv('D:\Home tasks\Datasets\StudentsPerformance.csv')
students_performance.columns = [x.replace(" ", "_") for x in students_performance.columns]
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
# строим гистограмму колонки math_score (метод matplotlib)
students_performance.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
# строим scatter-plot колонок math_score и reading_score (метод matplotlib)
students_performance.plot.scatter(x='math_score', y='reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
# scatter-plot в seaborn
ax = sb.lmplot(x='math_score', y='reading_score', hue='gender', data=students_performance, fit_reg=False)
# hue - группирующая переменная, fit_reg=False - бе регрессионных прямых
ax.set_xlabels('Math Score')
ax.set_ylabels('Reading Score')

# %%
sb.swarmplot(y='math_score', x='lunch', hue='gender',data=students_performance)
# Out:
# D:\Anaconda3\envs\keras\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='lunch', ylabel='math_score'>

# %%
# график зависимостей разными способами
df = pd.read_csv('D:\Home tasks\Datasets\income.csv')
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
sb.lineplot(data=df)
# sb.lineplot(x=df.index, y=df.income)
# df.plot() (matplotlb)
# df.plot(kind='line') (matplotlb)
# plt.plot(df.index, df.income) (matplotlb)
# df.income.plot()
# Out:
# <AxesSubplot:>

# %%
# heatmap - график
genome = pd.read_csv('D:\Home tasks\Datasets\genome_matrix.csv', index_col=0) # index_col - принять столбец в качестве индексов
genome
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
genome_plot = sb.heatmap(data=genome, cmap='viridis') # cmap - выбор цветовой схемы
genome_plot.xaxis.set_ticks_position('top') # надписи сверху
genome_plot.xaxis.set_tick_params(rotation=90) # поворот надписей на 90 гр. по часовой

# %%
# график средних с доверительными интервалами
sb.barplot(data=genome)
# Out:
# <AxesSubplot:>

# %%
dotaset = pd.read_csv('D:\Home tasks\Datasets\dota_hero_stats.csv')
dotaset
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
# гистограмма частот
dotaset['role_count'] = dotaset['roles'].str.split(',').str.len()
sb.histplot(data=dotaset['role_count'])
# Out:
# <AxesSubplot:xlabel='role_count', ylabel='Count'>

# %%
iriset = pd.read_csv('D:\Home tasks\Datasets\iris.csv', index_col=0)
iriset
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
#график с гистограммами и корреляцией
sb.pairplot(iriset)

# %%
sb.violinplot(y=iriset['petal length'])
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
sb.kdeplot(data=iriset['petal length'])
# Out:
# <AxesSubplot:xlabel='petal length', ylabel='Density'>

# %%
#2d KDE
sb.jointplot(x=iriset['petal length'], y=iriset['sepal width']) # kind=kde
